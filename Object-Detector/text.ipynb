# %%
response = {
    "TextDetections": [
        {
            "DetectedText": "IT'S",
            "Type": "LINE",
            "Id": 0,
            "Confidence": 99.91668701171875,
            "Geometry": {
                "BoundingBox": {
                    "Width": 0.14000000059604645,
                    "Height": 0.10000000149011612,
                    "Left": 0.6700000166893005,
                    "Top": 0.18000000715255737
                },
                "Polygon": [
                    {
                        "X": 0.6700000166893005,
                        "Y": 0.18000000715255737
                    },
                    {
                        "X": 0.8100000023841858,
                        "Y": 0.18000000715255737
                    },
                    {
                        "X": 0.8100000023841858,
                        "Y": 0.2800000011920929
                    },
                    {
                        "X": 0.6700000166893005,
                        "Y": 0.2800000011920929
                    }
                ]
            }
        },
        {
            "DetectedText": "MONDAY",
            "Type": "LINE",
            "Id": 1,
            "Confidence": 99.96659851074219,
            "Geometry": {
                "BoundingBox": {
                    "Width": 0.4000000059604645,
                    "Height": 0.11500000208616257,
                    "Left": 0.550000011920929,
                    "Top": 0.3449999988079071
                },
                "Polygon": [
                    {
                        "X": 0.550000011920929,
                        "Y": 0.3449999988079071
                    },
                    {
                        "X": 0.949999988079071,
                        "Y": 0.3449999988079071
                    },
                    {
                        "X": 0.949999988079071,
                        "Y": 0.46000000834465027
                    },
                    {
                        "X": 0.550000011920929,
                        "Y": 0.46000000834465027
                    }
                ]
            }
        },
        {
            "DetectedText": "but keep",
            "Type": "LINE",
            "Id": 2,
            "Confidence": 99.76813507080078,
            "Geometry": {
                "BoundingBox": {
                    "Width": 0.21148386597633362,
                    "Height": 0.10207264125347137,
                    "Left": 0.6342755556106567,
                    "Top": 0.5108879804611206
                },
                "Polygon": [
                    {
                        "X": 0.6369435787200928,
                        "Y": 0.5108879804611206
                    },
                    {
                        "X": 0.8457594513893127,
                        "Y": 0.525165855884552
                    },
                    {
                        "X": 0.8430914282798767,
                        "Y": 0.6129606366157532
                    },
                    {
                        "X": 0.6342755556106567,
                        "Y": 0.598682701587677
                    }
                ]
            }
        },
        {
            "DetectedText": "Smiling",
            "Type": "LINE",
            "Id": 3,
            "Confidence": 99.8887939453125,
            "Geometry": {
                "BoundingBox": {
                    "Width": 0.4814750552177429,
                    "Height": 0.3078942596912384,
                    "Left": 0.5042624473571777,
                    "Top": 0.6035528779029846
                },
                "Polygon": [
                    {
                        "X": 0.5042624473571777,
                        "Y": 0.6251089572906494
                    },
                    {
                        "X": 0.9799708724021912,
                        "Y": 0.6035528779029846
                    },
                    {
                        "X": 0.9857375621795654,
                        "Y": 0.8898910284042358
                    },
                    {
                        "X": 0.510029137134552,
                        "Y": 0.9114471077919006
                    }
                ]
            }
        },
        {
            "DetectedText": "IT'S",
            "Type": "WORD",
            "Id": 4,
            "ParentId": 0,
            "Confidence": 99.91668701171875,
            "Geometry": {
                "BoundingBox": {
                    "Width": 0.14000000059604645,
                    "Height": 0.10000000149011612,
                    "Left": 0.6700000166893005,
                    "Top": 0.18000000715255737
                },
                "Polygon": [
                    {
                        "X": 0.6700000166893005,
                        "Y": 0.18000000715255737
                    },
                    {
                        "X": 0.8100000023841858,
                        "Y": 0.18000000715255737
                    },
                    {
                        "X": 0.8100000023841858,
                        "Y": 0.2800000011920929
                    },
                    {
                        "X": 0.6700000166893005,
                        "Y": 0.2800000011920929
                    }
                ]
            }
        },
        {
            "DetectedText": "MONDAY",
            "Type": "WORD",
            "Id": 5,
            "ParentId": 1,
            "Confidence": 99.96659851074219,
            "Geometry": {
                "BoundingBox": {
                    "Width": 0.4000000059604645,
                    "Height": 0.11500000208616257,
                    "Left": 0.550000011920929,
                    "Top": 0.3449999988079071
                },
                "Polygon": [
                    {
                        "X": 0.550000011920929,
                        "Y": 0.3449999988079071
                    },
                    {
                        "X": 0.949999988079071,
                        "Y": 0.3449999988079071
                    },
                    {
                        "X": 0.949999988079071,
                        "Y": 0.46000000834465027
                    },
                    {
                        "X": 0.550000011920929,
                        "Y": 0.46000000834465027
                    }
                ]
            }
        },
        {
            "DetectedText": "but",
            "Type": "WORD",
            "Id": 6,
            "ParentId": 2,
            "Confidence": 99.93682861328125,
            "Geometry": {
                "BoundingBox": {
                    "Width": 0.08666666597127914,
                    "Height": 0.06499999761581421,
                    "Left": 0.6366666555404663,
                    "Top": 0.5199999809265137
                },
                "Polygon": [
                    {
                        "X": 0.6366666555404663,
                        "Y": 0.5199999809265137
                    },
                    {
                        "X": 0.7233333587646484,
                        "Y": 0.5199999809265137
                    },
                    {
                        "X": 0.7233333587646484,
                        "Y": 0.5849999785423279
                    },
                    {
                        "X": 0.6366666555404663,
                        "Y": 0.5849999785423279
                    }
                ]
            }
        },
        {
            "DetectedText": "keep",
            "Type": "WORD",
            "Id": 7,
            "ParentId": 2,
            "Confidence": 99.59944152832031,
            "Geometry": {
                "BoundingBox": {
                    "Width": 0.11666666716337204,
                    "Height": 0.07999999821186066,
                    "Left": 0.7266666889190674,
                    "Top": 0.5249999761581421
                },
                "Polygon": [
                    {
                        "X": 0.7266666889190674,
                        "Y": 0.5249999761581421
                    },
                    {
                        "X": 0.8433333039283752,
                        "Y": 0.5249999761581421
                    },
                    {
                        "X": 0.8433333039283752,
                        "Y": 0.6050000190734863
                    },
                    {
                        "X": 0.7266666889190674,
                        "Y": 0.6050000190734863
                    }
                ]
            }
        },
        {
            "DetectedText": "Smiling",
            "Type": "WORD",
            "Id": 8,
            "ParentId": 3,
            "Confidence": 99.8887939453125,
            "Geometry": {
                "BoundingBox": {
                    "Width": 0.47375568747520447,
                    "Height": 0.28501948714256287,
                    "Left": 0.5066666603088379,
                    "Top": 0.625
                },
                "Polygon": [
                    {
                        "X": 0.5066666603088379,
                        "Y": 0.625
                    },
                    {
                        "X": 0.9800000190734863,
                        "Y": 0.6050000190734863
                    },
                    {
                        "X": 0.9833333492279053,
                        "Y": 0.8899999856948853
                    },
                    {
                        "X": 0.5099999904632568,
                        "Y": 0.9100000262260437
                    }
                ]
            }
        }
    ],
    "TextModelVersion": "3.0"
}

# %%
for i in range(len(response['TextDetections'])):
    if response['TextDetections'][i]['Type'] == 'WORD':
        print(response['TextDetections'][i]['DetectedText'])
# Out:
# IT'S
# MONDAY
# but
# keep
# Smiling
