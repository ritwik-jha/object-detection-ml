# %%
response = {
    "FaceDetails": [
        {
            "BoundingBox": {
                "Width": 0.18937082588672638,
                "Height": 0.4006582796573639,
                "Left": 0.2870060205459595,
                "Top": 0.12157715111970901
            },
            "AgeRange": {
                "Low": 22,
                "High": 34
            },
            "Smile": {
                "Value": True,
                "Confidence": 99.95774841308594
            },
            "Eyeglasses": {
                "Value": False,
                "Confidence": 95.36972045898438
            },
            "Sunglasses": {
                "Value": False,
                "Confidence": 98.72027587890625
            },
            "Gender": {
                "Value": "Male",
                "Confidence": 99.46373748779297
            },
            "Beard": {
                "Value": True,
                "Confidence": 93.94589233398438
            },
            "Mustache": {
                "Value": False,
                "Confidence": 68.94478607177734
            },
            "EyesOpen": {
                "Value": True,
                "Confidence": 97.35838317871094
            },
            "MouthOpen": {
                "Value": True,
                "Confidence": 99.90689086914062
            },
            "Emotions": [
                {
                    "Type": "HAPPY",
                    "Confidence": 99.77570343017578
                },
                {
                    "Type": "SURPRISED",
                    "Confidence": 0.06526943296194077
                },
                {
                    "Type": "ANGRY",
                    "Confidence": 0.048588383942842484
                },
                {
                    "Type": "CONFUSED",
                    "Confidence": 0.03426136076450348
                },
                {
                    "Type": "FEAR",
                    "Confidence": 0.0309746153652668
                },
                {
                    "Type": "DISGUSTED",
                    "Confidence": 0.029897602275013924
                },
                {
                    "Type": "SAD",
                    "Confidence": 0.010117271915078163
                },
                {
                    "Type": "CALM",
                    "Confidence": 0.005187215283513069
                }
            ],
            "Landmarks": [
                {
                    "Type": "eyeLeft",
                    "X": 0.34175100922584534,
                    "Y": 0.2763494849205017
                },
                {
                    "Type": "eyeRight",
                    "X": 0.42029869556427,
                    "Y": 0.3119548559188843
                },
                {
                    "Type": "mouthLeft",
                    "X": 0.3253549039363861,
                    "Y": 0.40165790915489197
                },
                {
                    "Type": "mouthRight",
                    "X": 0.3908734619617462,
                    "Y": 0.43145060539245605
                },
                {
                    "Type": "nose",
                    "X": 0.3654763400554657,
                    "Y": 0.36656099557876587
                },
                {
                    "Type": "leftEyeBrowLeft",
                    "X": 0.3188592493534088,
                    "Y": 0.23158332705497742
                },
                {
                    "Type": "leftEyeBrowRight",
                    "X": 0.34287381172180176,
                    "Y": 0.23144161701202393
                },
                {
                    "Type": "leftEyeBrowUp",
                    "X": 0.3637997806072235,
                    "Y": 0.24949242174625397
                },
                {
                    "Type": "rightEyeBrowLeft",
                    "X": 0.40860894322395325,
                    "Y": 0.2695733904838562
                },
                {
                    "Type": "rightEyeBrowRight",
                    "X": 0.43320637941360474,
                    "Y": 0.27194684743881226
                },
                {
                    "Type": "rightEyeBrowUp",
                    "X": 0.4553125202655792,
                    "Y": 0.2929185628890991
                },
                {
                    "Type": "leftEyeLeft",
                    "X": 0.3282102048397064,
                    "Y": 0.26840221881866455
                },
                {
                    "Type": "leftEyeRight",
                    "X": 0.3570117652416229,
                    "Y": 0.2842460870742798
                },
                {
                    "Type": "leftEyeUp",
                    "X": 0.3424626290798187,
                    "Y": 0.2703678011894226
                },
                {
                    "Type": "leftEyeDown",
                    "X": 0.3409899175167084,
                    "Y": 0.2817520201206207
                },
                {
                    "Type": "rightEyeLeft",
                    "X": 0.40440988540649414,
                    "Y": 0.30568593740463257
                },
                {
                    "Type": "rightEyeRight",
                    "X": 0.4346146285533905,
                    "Y": 0.31648269295692444
                },
                {
                    "Type": "rightEyeUp",
                    "X": 0.4212769567966461,
                    "Y": 0.3059920370578766
                },
                {
                    "Type": "rightEyeDown",
                    "X": 0.4187729060649872,
                    "Y": 0.3169322907924652
                },
                {
                    "Type": "noseLeft",
                    "X": 0.3499370217323303,
                    "Y": 0.3686228096485138
                },
                {
                    "Type": "noseRight",
                    "X": 0.3789599537849426,
                    "Y": 0.3816491663455963
                },
                {
                    "Type": "mouthUp",
                    "X": 0.3587522804737091,
                    "Y": 0.40487462282180786
                },
                {
                    "Type": "mouthDown",
                    "X": 0.35230427980422974,
                    "Y": 0.44048601388931274
                },
                {
                    "Type": "leftPupil",
                    "X": 0.34175100922584534,
                    "Y": 0.2763494849205017
                },
                {
                    "Type": "rightPupil",
                    "X": 0.42029869556427,
                    "Y": 0.3119548559188843
                },
                {
                    "Type": "upperJawlineLeft",
                    "X": 0.2998393774032593,
                    "Y": 0.24502968788146973
                },
                {
                    "Type": "midJawlineLeft",
                    "X": 0.2904193699359894,
                    "Y": 0.38642436265945435
                },
                {
                    "Type": "chinBottom",
                    "X": 0.3418397903442383,
                    "Y": 0.500682532787323
                },
                {
                    "Type": "midJawlineRight",
                    "X": 0.429293692111969,
                    "Y": 0.4485112726688385
                },
                {
                    "Type": "upperJawlineRight",
                    "X": 0.47091734409332275,
                    "Y": 0.32162439823150635
                }
            ],
            "Pose": {
                "Roll": 16.74009895324707,
                "Yaw": -3.8840701580047607,
                "Pitch": -1.0144727230072021
            },
            "Quality": {
                "Brightness": 62.87778091430664,
                "Sharpness": 78.64350128173828
            },
            "Confidence": 99.99821472167969
        },
        {
            "BoundingBox": {
                "Width": 0.18808934092521667,
                "Height": 0.323091059923172,
                "Left": 0.4571535587310791,
                "Top": 0.14800293743610382
            },
            "AgeRange": {
                "Low": 22,
                "High": 34
            },
            "Smile": {
                "Value": True,
                "Confidence": 99.82666015625
            },
            "Eyeglasses": {
                "Value": False,
                "Confidence": 99.67113494873047
            },
            "Sunglasses": {
                "Value": False,
                "Confidence": 99.8966293334961
            },
            "Gender": {
                "Value": "Female",
                "Confidence": 99.84819030761719
            },
            "Beard": {
                "Value": False,
                "Confidence": 99.6822738647461
            },
            "Mustache": {
                "Value": False,
                "Confidence": 99.86566162109375
            },
            "EyesOpen": {
                "Value": True,
                "Confidence": 99.52324676513672
            },
            "MouthOpen": {
                "Value": True,
                "Confidence": 99.05750274658203
            },
            "Emotions": [
                {
                    "Type": "HAPPY",
                    "Confidence": 99.576171875
                },
                {
                    "Type": "SURPRISED",
                    "Confidence": 0.12516094744205475
                },
                {
                    "Type": "FEAR",
                    "Confidence": 0.12296560406684875
                },
                {
                    "Type": "CONFUSED",
                    "Confidence": 0.050113316625356674
                },
                {
                    "Type": "SAD",
                    "Confidence": 0.047242775559425354
                },
                {
                    "Type": "ANGRY",
                    "Confidence": 0.0334664061665535
                },
                {
                    "Type": "DISGUSTED",
                    "Confidence": 0.03046739473938942
                },
                {
                    "Type": "CALM",
                    "Confidence": 0.014416835270822048
                }
            ],
            "Landmarks": [
                {
                    "Type": "eyeLeft",
                    "X": 0.5374342799186707,
                    "Y": 0.259536474943161
                },
                {
                    "Type": "eyeRight",
                    "X": 0.5985921621322632,
                    "Y": 0.3275623321533203
                },
                {
                    "Type": "mouthLeft",
                    "X": 0.49902647733688354,
                    "Y": 0.3602932095527649
                },
                {
                    "Type": "mouthRight",
                    "X": 0.5502210855484009,
                    "Y": 0.41766655445098877
                },
                {
                    "Type": "nose",
                    "X": 0.5351046919822693,
                    "Y": 0.35161399841308594
                },
                {
                    "Type": "leftEyeBrowLeft",
                    "X": 0.5275004506111145,
                    "Y": 0.20988252758979797
                },
                {
                    "Type": "leftEyeBrowRight",
                    "X": 0.5457935929298401,
                    "Y": 0.2220839262008667
                },
                {
                    "Type": "leftEyeBrowUp",
                    "X": 0.5594671368598938,
                    "Y": 0.24789270758628845
                },
                {
                    "Type": "rightEyeBrowLeft",
                    "X": 0.5943886637687683,
                    "Y": 0.2862367331981659
                },
                {
                    "Type": "rightEyeBrowRight",
                    "X": 0.6161555051803589,
                    "Y": 0.2993444502353668
                },
                {
                    "Type": "rightEyeBrowUp",
                    "X": 0.63376784324646,
                    "Y": 0.3269082009792328
                },
                {
                    "Type": "leftEyeLeft",
                    "X": 0.5278059840202332,
                    "Y": 0.2460840791463852
                },
                {
                    "Type": "leftEyeRight",
                    "X": 0.5489632487297058,
                    "Y": 0.2737892270088196
                },
                {
                    "Type": "leftEyeUp",
                    "X": 0.5388301014900208,
                    "Y": 0.25492191314697266
                },
                {
                    "Type": "leftEyeDown",
                    "X": 0.5355263352394104,
                    "Y": 0.2640328109264374
                },
                {
                    "Type": "rightEyeLeft",
                    "X": 0.5858702063560486,
                    "Y": 0.31470176577568054
                },
                {
                    "Type": "rightEyeRight",
                    "X": 0.610679566860199,
                    "Y": 0.3379613757133484
                },
                {
                    "Type": "rightEyeUp",
                    "X": 0.6002165675163269,
                    "Y": 0.3229897618293762
                },
                {
                    "Type": "rightEyeDown",
                    "X": 0.5961177945137024,
                    "Y": 0.33129236102104187
                },
                {
                    "Type": "noseLeft",
                    "X": 0.524066150188446,
                    "Y": 0.34498921036720276
                },
                {
                    "Type": "noseRight",
                    "X": 0.5467027425765991,
                    "Y": 0.3699130117893219
                },
                {
                    "Type": "mouthUp",
                    "X": 0.5242531895637512,
                    "Y": 0.38082125782966614
                },
                {
                    "Type": "mouthDown",
                    "X": 0.5123893022537231,
                    "Y": 0.4085330665111542
                },
                {
                    "Type": "leftPupil",
                    "X": 0.5374342799186707,
                    "Y": 0.259536474943161
                },
                {
                    "Type": "rightPupil",
                    "X": 0.5985921621322632,
                    "Y": 0.3275623321533203
                },
                {
                    "Type": "upperJawlineLeft",
                    "X": 0.5146453380584717,
                    "Y": 0.21030627191066742
                },
                {
                    "Type": "midJawlineLeft",
                    "X": 0.47816282510757446,
                    "Y": 0.32902073860168457
                },
                {
                    "Type": "chinBottom",
                    "X": 0.4939490854740143,
                    "Y": 0.4548918306827545
                },
                {
                    "Type": "midJawlineRight",
                    "X": 0.5862583518028259,
                    "Y": 0.4472740888595581
                },
                {
                    "Type": "upperJawlineRight",
                    "X": 0.6478132605552673,
                    "Y": 0.35618025064468384
                }
            ],
            "Pose": {
                "Roll": 35.116737365722656,
                "Yaw": -3.9238367080688477,
                "Pitch": -10.206050872802734
            },
            "Quality": {
                "Brightness": 71.05132293701172,
                "Sharpness": 73.32209777832031
            },
            "Confidence": 99.99537658691406
        },
        {
            "BoundingBox": {
                "Width": 0.15803489089012146,
                "Height": 0.31513917446136475,
                "Left": 0.13250024616718292,
                "Top": 0.1704401969909668
            },
            "AgeRange": {
                "Low": 5,
                "High": 15
            },
            "Smile": {
                "Value": True,
                "Confidence": 99.93268585205078
            },
            "Eyeglasses": {
                "Value": False,
                "Confidence": 99.53880310058594
            },
            "Sunglasses": {
                "Value": False,
                "Confidence": 99.84123992919922
            },
            "Gender": {
                "Value": "Female",
                "Confidence": 99.237060546875
            },
            "Beard": {
                "Value": False,
                "Confidence": 99.01219177246094
            },
            "Mustache": {
                "Value": False,
                "Confidence": 99.73258972167969
            },
            "EyesOpen": {
                "Value": True,
                "Confidence": 96.92729949951172
            },
            "MouthOpen": {
                "Value": True,
                "Confidence": 99.72455596923828
            },
            "Emotions": [
                {
                    "Type": "HAPPY",
                    "Confidence": 99.82382202148438
                },
                {
                    "Type": "FEAR",
                    "Confidence": 0.04268808290362358
                },
                {
                    "Type": "SURPRISED",
                    "Confidence": 0.037457551807165146
                },
                {
                    "Type": "CONFUSED",
                    "Confidence": 0.025377506390213966
                },
                {
                    "Type": "DISGUSTED",
                    "Confidence": 0.024003122001886368
                },
                {
                    "Type": "SAD",
                    "Confidence": 0.021748801693320274
                },
                {
                    "Type": "ANGRY",
                    "Confidence": 0.02114896848797798
                },
                {
                    "Type": "CALM",
                    "Confidence": 0.0037649639416486025
                }
            ],
            "Landmarks": [
                {
                    "Type": "eyeLeft",
                    "X": 0.20125962793827057,
                    "Y": 0.30110734701156616
                },
                {
                    "Type": "eyeRight",
                    "X": 0.2646893262863159,
                    "Y": 0.313548743724823
                },
                {
                    "Type": "mouthLeft",
                    "X": 0.19416075944900513,
                    "Y": 0.4067131280899048
                },
                {
                    "Type": "mouthRight",
                    "X": 0.24704334139823914,
                    "Y": 0.41639962792396545
                },
                {
                    "Type": "nose",
                    "X": 0.2449537068605423,
                    "Y": 0.365866482257843
                },
                {
                    "Type": "leftEyeBrowLeft",
                    "X": 0.1733708679676056,
                    "Y": 0.2709062993526459
                },
                {
                    "Type": "leftEyeBrowRight",
                    "X": 0.20305778086185455,
                    "Y": 0.2636771500110626
                },
                {
                    "Type": "leftEyeBrowUp",
                    "X": 0.2242937833070755,
                    "Y": 0.2735089659690857
                },
                {
                    "Type": "rightEyeBrowLeft",
                    "X": 0.2606615424156189,
                    "Y": 0.2812221050262451
                },
                {
                    "Type": "rightEyeBrowRight",
                    "X": 0.27633917331695557,
                    "Y": 0.27899008989334106
                },
                {
                    "Type": "rightEyeBrowUp",
                    "X": 0.2838557958602905,
                    "Y": 0.29309991002082825
                },
                {
                    "Type": "leftEyeLeft",
                    "X": 0.18742629885673523,
                    "Y": 0.2979690432548523
                },
                {
                    "Type": "leftEyeRight",
                    "X": 0.21342240273952484,
                    "Y": 0.3043753206729889
                },
                {
                    "Type": "leftEyeUp",
                    "X": 0.20253907144069672,
                    "Y": 0.2959018349647522
                },
                {
                    "Type": "leftEyeDown",
                    "X": 0.20088884234428406,
                    "Y": 0.3057245910167694
                },
                {
                    "Type": "rightEyeLeft",
                    "X": 0.25173360109329224,
                    "Y": 0.3120063841342926
                },
                {
                    "Type": "rightEyeRight",
                    "X": 0.27347034215927124,
                    "Y": 0.3148657977581024
                },
                {
                    "Type": "rightEyeUp",
                    "X": 0.2662595808506012,
                    "Y": 0.30853334069252014
                },
                {
                    "Type": "rightEyeDown",
                    "X": 0.26375913619995117,
                    "Y": 0.31798672676086426
                },
                {
                    "Type": "noseLeft",
                    "X": 0.2198946326971054,
                    "Y": 0.3728989362716675
                },
                {
                    "Type": "noseRight",
                    "X": 0.2434644103050232,
                    "Y": 0.37756431102752686
                },
                {
                    "Type": "mouthUp",
                    "X": 0.23040784895420074,
                    "Y": 0.4001958668231964
                },
                {
                    "Type": "mouthDown",
                    "X": 0.22404469549655914,
                    "Y": 0.4309444725513458
                },
                {
                    "Type": "leftPupil",
                    "X": 0.20125962793827057,
                    "Y": 0.30110734701156616
                },
                {
                    "Type": "rightPupil",
                    "X": 0.2646893262863159,
                    "Y": 0.313548743724823
                },
                {
                    "Type": "upperJawlineLeft",
                    "X": 0.13373838365077972,
                    "Y": 0.28969502449035645
                },
                {
                    "Type": "midJawlineLeft",
                    "X": 0.13710270822048187,
                    "Y": 0.4053010642528534
                },
                {
                    "Type": "chinBottom",
                    "X": 0.20952026546001434,
                    "Y": 0.48320502042770386
                },
                {
                    "Type": "midJawlineRight",
                    "X": 0.24993540346622467,
                    "Y": 0.4281526803970337
                },
                {
                    "Type": "upperJawlineRight",
                    "X": 0.2725149393081665,
                    "Y": 0.31823834776878357
                }
            ],
            "Pose": {
                "Roll": 8.611062049865723,
                "Yaw": 21.65570831298828,
                "Pitch": 0.9987683296203613
            },
            "Quality": {
                "Brightness": 84.89690399169922,
                "Sharpness": 83.14741516113281
            },
            "Confidence": 99.99116516113281
        }
    ]
}

# %%
response['FaceDetails'][0]
# Out:
# {'BoundingBox': {'Width': 0.18937082588672638,
#   'Height': 0.4006582796573639,
#   'Left': 0.2870060205459595,
#   'Top': 0.12157715111970901},
#  'AgeRange': {'Low': 22, 'High': 34},
#  'Smile': {'Value': True, 'Confidence': 99.95774841308594},
#  'Eyeglasses': {'Value': False, 'Confidence': 95.36972045898438},
#  'Sunglasses': {'Value': False, 'Confidence': 98.72027587890625},
#  'Gender': {'Value': 'Male', 'Confidence': 99.46373748779297},
#  'Beard': {'Value': True, 'Confidence': 93.94589233398438},
#  'Mustache': {'Value': False, 'Confidence': 68.94478607177734},
#  'EyesOpen': {'Value': True, 'Confidence': 97.35838317871094},
#  'MouthOpen': {'Value': True, 'Confidence': 99.90689086914062},
#  'Emotions': [{'Type': 'HAPPY', 'Confidence': 99.77570343017578},
#   {'Type': 'SURPRISED', 'Confidence': 0.06526943296194077},
#   {'Type': 'ANGRY', 'Confidence': 0.048588383942842484},
#   {'Type': 'CONFUSED', 'Confidence': 0.03426136076450348},
# ...

# %%
from PIL import Image, ImageDraw, ExifTags, ImageColor
image=Image.open('family_resized.jpg')
imgWidth, imgHeight = image.size
draw = ImageDraw.Draw(image)
image.show()

# %%
x = response['FaceDetails']
y = x[0]
box = y['BoundingBox']
w = box['Width']
h = box['Height']
l = box['Left']
t = box['Top']
left = imgWidth * l
top = imgHeight * t
width = imgWidth * w
height = imgHeight * h
points = (
         (left,top),
        (left + width, top),
     (left + width, top + height),
     (left , top + height),
     (left, top)
         )
#draw.line(points, fill='#00d400', width=10)
#draw.rectangle([left,top, left + width, top + height], outline='green')
image.crop((left, top, left+width, top+height))
image.show()
